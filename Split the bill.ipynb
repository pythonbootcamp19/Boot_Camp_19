# %% [markdown]
# How solve a problem? Or build something?
#
# 1st Define the problem
# 2nd what is the input and what is the output?
# 3rd If the problem is big (or a large number of people) then break it down to 2 people first. Break it down into very small chunck.

# %%
print("Bill spliting App\n")

print("what was the total bill?")

total_bill = int(input())

print("\n")

print("What is your name?", end=' ')
u1_name = input()
print("What was your bill?", end=' ')
u1_bill = int(input())
print("How much did you pay?", end=' ')
u1_paid = int(input())

total_u1 = u1_bill - u1_paid

print(f"so, {u1_name} your bill was {u1_bill}, you paid {u1_paid}, which means you owe (or receive) {total_u1}")

print("\n")

print("What is your name?", end=' ')
u2_name = input()
print("What was your bill?", end=' ')
u2_bill = int(input())
print("How much did you pay?", end=' ')
u2_paid = int(input())

total_u2 = u2_bill - u2_paid

print(f"so, {u2_name} your bill was {u2_bill}, you paid {u2_paid}, which means you owe (or receive) {total_u2}")


print("\n")


print("What is your name?", end=' ')
u3_name = input()
print("What was your bill?", end=' ')
u3_bill = int(input())
print("How much did you pay?", end=' ')
u3_paid = int(input())

total_u3 = u3_bill - u3_paid

print(f"so, {u3_name} your bill was {u3_bill}, you paid {u3_paid}, which means you owe (or receive) {total_u3}")


print("\n")


print("What is your name?", end=' ')
u4_name = input()
print("What was your bill?", end=' ')
u4_bill = int(input())
print("How much did you pay?", end=' ')
u4_paid = int(input())

total_u4 = u4_bill - u4_paid

print(f"so, {u4_name} your bill was {u4_bill}, you paid {u4_paid}, which means you owe (or receive) {total_u4}")

print("\n")
# Out:
# Bill spliting App
#
# what was the total bill?
# 500
#
#
# What is your name? Vik
# What was your bill? 50
# How much did you pay? 0
# so, Vik your bill was 50, you paid 0, which means you owe (or receive) 50
#
#
# What is your name? Hasan
# What was your bill? 30
# How much did you pay? 200
# so, Hasan your bill was 30, you paid 200, which means you owe (or receive) -170
#
#
# What is your name? Srinivas
# What was your bill? 120
# How much did you pay? 200
# so, Srinivas your bill was 120, you paid 200, which means you owe (or receive) -80
#
#
# What is your name? Lorenzo
# What was your bill? 300
# How much did you pay? 100
# so, Lorenzo your bill was 300, you paid 100, which means you owe (or receive) 200
