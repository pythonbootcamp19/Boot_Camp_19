# %%
#go to: https://github.com/public-apis/public-apis#animals
# go to : animal
# dog (or any other image)

import requests
import json

def get_random_dog_image():
    """ This function goes to the dog.ceo api and fetch a random dog image
    The return value is a json dict and it returns a single image url as a string.
    """
    
    random_dog_api = "https://dog.ceo/api/breeds/image/random"
    response = requests.get(random_dog_api)
    image_dict = json.loads(response.content)
    #print(image_dict)
    return image_dict["message"]

dog_image_url = get_random_dog_image()
print(dog_image_url)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         try:
# --> 344             self._validate_conn(conn)
#     345         except (SocketTimeout, BaseSSLError) as e:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     842         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 843             conn.connect()
#     844
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     315         # Add certificate verification
# --> 316         conn = self._new_conn()
#     317         hostname = self.host
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e)
#     170
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x1108f47f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='dog.ceo', port=443): Max retries exceeded with url: /api/breeds/image/random (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1108f47f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-1-29ac63d7ce6c> in <module>
#      17     return image_dict["message"]
#      18
# ---> 19 dog_image_url = get_random_dog_image()
#      20 print(dog_image_url)
#
# <ipython-input-1-29ac63d7ce6c> in get_random_dog_image()
#      12
#      13     random_dog_api = "https://dog.ceo/api/breeds/image/random"
# ---> 14     response = requests.get(random_dog_api)
#      15     image_dict = json.loads(response.content)
#      16     #print(image_dict)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='dog.ceo', port=443): Max retries exceeded with url: /api/breeds/image/random (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1108f47f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %%
#Version 1 image downloader
image_response = requests.get(dog_image_url)
#print(image_response.content)
image_data = image_response.content
image_file = open("test_image.jpg", "wb") #write binary data
image_file.write(image_data)
image_file.close()

# %%
#Version 2 image downloader

def image_downloader(dog_image_url):
    """This function takes an image url and 
    download the image to a file with the 
    file name from the url
    """

    image_name = dog_image_url.split("/")[-1]

    image_response = requests.get(dog_image_url)
    image_data = image_response.content

    image_file = open("test_image.jpg", "wb") #write binary data
    image_file.write(image_data)
    image_file.close()
    return 0

result = image_downloader(dog_image_url)
print("image downloaded.")
# Out:
# image downloaded.

# %%
def get_random_dog_image():
    """ This function goes to the dog.ceo api and fetch a random dog image
    The return value is a json dict and it returns a single image url as a string.
    """
    
    random_dog_api = "https://dog.ceo/api/breeds/image/random"
    response = requests.get(random_dog_api)
    image_dict = json.loads(response.content)
    #print(image_dict)
    return image_dict["message"]

def image_downloader(dog_image_url):
    """This function takes an image url and 
    download the image to a file with the 
    file name from the url
    """

    image_name = dog_image_url.split("/")[-1]

    image_response = requests.get(dog_image_url)
    image_data = image_response.content

    image_file = open(image_name, "wb") #write binary data
    image_file.write(image_data)
    image_file.close()
    print(image_name,"dowloaded.")
    return 0


dog_image_url = get_random_dog_image()
result = image_downloader(dog_image_url)

# print("image downloaded.")
# print(dog_image_url)
# Out:
# Daschund_Wirehair.jpg dowloaded.

# %%
import requests
import json

def get_breed_list():
    
    breed_list_url = "https://dog.ceo/api/breeds/list/all"

    response = requests.get(breed_list_url)
    
    response_dict = json.loads(response.content)
    breed_list = list(response_dict["message"].keys())
    #print(breed_list)
    
    return breed_list

# breed_list = get_breed_list()
# dog_breed = breed_list[0]

def get_breed_image_url(dog_breed):
    dog_breed_image_url = f"https://dog.ceo/api/breed/{dog_breed}/images/random"
    response_data = requests.get(dog_breed_image_url).content
    image_dict = json.loads(response_data)
    return image_dict["message"]

breed_list = get_breed_list()

for i in range(len(breed_list)):
    print(i, breed_list[i])
breed_num = int(input("Please enter the breed number: "))


dog_breed = breed_list[breed_num]
image_url = get_breed_image_url(dog_breed)
print(image_url)
# Out:
# 0 affenpinscher
# 1 african
# 2 airedale
# 3 akita
# 4 appenzeller
# 5 basenji
# 6 beagle
# 7 bluetick
# 8 borzoi
# 9 bouvier
# 10 boxer
# 11 brabancon
# 12 briard
# 13 bulldog
# 14 bullterrier
# 15 cairn
# 16 cattledog
# 17 chihuahua
# 18 chow
# 19 clumber
# 20 cockapoo
# 21 collie
# 22 coonhound
# 23 corgi
# 24 cotondetulear
# 25 dachshund
# 26 dalmatian
# 27 dane
# 28 deerhound
# 29 dhole
# 30 dingo
# 31 doberman
# 32 elkhound
# 33 entlebucher
# 34 eskimo
# 35 frise
# 36 germanshepherd
# 37 greyhound
# 38 groenendael
# 39 hound
# 40 husky
# 41 keeshond
# 42 kelpie
# 43 komondor
# 44 kuvasz
# 45 labrador
# 46 leonberg
# 47 lhasa
# 48 malamute
# 49 malinois
# 50 maltese
# 51 mastiff
# 52 mexicanhairless
# 53 mix
# 54 mountain
# 55 newfoundland
# 56 otterhound
# 57 papillon
# 58 pekinese
# 59 pembroke
# 60 pinscher
# 61 pointer
# 62 pomeranian
# 63 poodle
# 64 pug
# 65 puggle
# 66 pyrenees
# 67 redbone
# 68 retriever
# 69 ridgeback
# 70 rottweiler
# 71 saluki
# 72 samoyed
# 73 schipperke
# 74 schnauzer
# 75 setter
# 76 sheepdog
# 77 shiba
# 78 shihtzu
# 79 spaniel
# 80 springer
# 81 stbernard
# 82 terrier
# 83 vizsla
# 84 weimaraner
# 85 whippet
# 86 wolfhound
# Please enter the breed number: 31
# https://images.dog.ceo/breeds/doberman/n02107142_10952.jpg
